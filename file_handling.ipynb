# %%
import os

# %%
print('Current Working Directory is : ', os.getcwd())
# Out:
# Current Working Directory is :  c:\Users\LENOVO\Documents\DP-2025-PYTHON-9.30-MTWTFS

# %%
files = os.listdir()
print('Files in current working directory', files)
# Out:
# Files in current working directory ['.git', 'base.py', 'basics.ipynb', 'Data Structures', 'datatypes.ipynb', 'file_handling.ipynb', 'functions.ipynb', 'libraries.ipynb', 'loops.ipynb']

# %%
files = os.listdir(r"C:\Users\LENOVO\Documents\Brain_tumor_detection")
print('Files in specified directory : ',files)
print('Number of files in specified directory : ', len(files))
# Out:
# Files in specified directory :  ['.git', 'app.py', 'assets', 'batch_predict.py', 'brain_tumor_detection_model.ipynb', 'efficientnetB0.keras', 'instance', 'logs', 'migrations', 'mri scan', 'predict.py', 'README.md', 'requirements.txt', 'static', 'templates', 'tumour data', 'tuner_dir', 'untitled_project', 'uploads', 'users.db', '__pycache__']
# Number of files in specified directory :  21

# %%
total_files = 0
for path, folders, files in os.walk(r"C:\Users\LENOVO\Documents\Brain_tumor_detection"):
    print('=>', path)
    print('📂', folders)
    print('🗄️', files)
    total_files += len(files)
print('Total Files in directory tree: ', total_files)
# Out:
# => C:\Users\LENOVO\Documents\Brain_tumor_detection
# 📂 ['.git', 'assets', 'instance', 'logs', 'migrations', 'mri scan', 'static', 'templates', 'tumour data', 'tuner_dir', 'untitled_project', 'uploads', '__pycache__']
# 🗄️ ['app.py', 'batch_predict.py', 'brain_tumor_detection_model.ipynb', 'efficientnetB0.keras', 'predict.py', 'README.md', 'requirements.txt', 'users.db']
# => C:\Users\LENOVO\Documents\Brain_tumor_detection\.git
# 📂 ['hooks', 'info', 'logs', 'objects', 'refs']
# 🗄️ ['config', 'description', 'FETCH_HEAD', 'HEAD', 'index', 'packed-refs']
# => C:\Users\LENOVO\Documents\Brain_tumor_detection\.git\hooks
# 📂 []
# 🗄️ ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'sendemail-validate.sample', 'update.sample']
# ...

# %%
files = r"C:\Users\LENOVO\Documents\DP-2025-PYTHON-9.30-MTWTFS\loops.ipynb"
if os.path.exists(files):
    print("The file exists")
else:
    print("The file dows not exists")
# Out:
# The file exists
